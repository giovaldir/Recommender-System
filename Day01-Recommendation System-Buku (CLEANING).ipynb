# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # CLEANING

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/PORTFOLIO GIOVALDI/RECOMMENDER SYSTEM/buku.csv")
df.head(1)
# Out:
#    book_id  goodreads_book_id                      authors  \
# 0       27                  1  J.K. Rowling, Mary GrandPré
#
#    original_publication_year                          original_title  \
# 0                     2005.0  Harry Potter and the Half-Blood Prince
#
#                                                title language_code  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...           eng
#
#    average_rating  ratings_count  \
# 0            4.54        1678823
#
#                                     medium_image_url  \
# 0  https://images.gr-assets.com/books/1361039191m...
#
#                                      small_image_url  \
# 0  https://images.gr-assets.com/books/1361039191s...
#
#                                                 desc    genre  \
# 0  \r\nWhen Harry Potter and the Half-Blood Princ...  fantasy
#
#                                            image_url
# 0  https://images.gr-assets.com/books/1361039191l...

# %%
df_describe =[]

for i in df.columns:
    df_describe.append([
        i,
        df[i].dtypes,
        df[i].isna().sum(),
        round((((df[i].isna().sum())/(len(df)))*100),2),
        df[i].nunique(),
        df[i].unique()
    ])

DESC = pd.DataFrame(df_describe, columns=['column','type','nan','nan%','nunique','unique']) #memberi nama kolom 
DESC
# Out:
#                        column     type   nan   nan%  nunique  \
# 0                     book_id    int64     0   0.00    10000
# 1           goodreads_book_id    int64     0   0.00    10000
# 2                     authors   object     0   0.00     4664
# 3   original_publication_year  float64    21   0.21      293
# 4              original_title   object   585   5.85     9274
# 5                       title   object     0   0.00     9964
# 6               language_code   object  1084  10.84       25
# 7              average_rating  float64     0   0.00      184
# 8               ratings_count    int64     0   0.00     9003
# 9            medium_image_url   object     0   0.00     6669
# 10            small_image_url   object     0   0.00     6669
# 11                       desc   object     2   0.02      589
# 12                      genre   object     5   0.05      292
# 13                  image_url   object     0   0.00     6669
#
#                                                unique
# 0   [27, 21, 2, 18, 24, 3275, 3753, 54, 337, 374, ...
# 1   [1, 2, 3, 5, 6, 8, 10, 11, 13, 21, 24, 25, 26,...
# 2   [J.K. Rowling, Mary GrandPré, J.K. Rowling, Ma...
# 3   [2005.0, 2003.0, 1997.0, 1999.0, 2000.0, 1979....
# 4   [Harry Potter and the Half-Blood Prince, Harry...
# 5   [Harry Potter and the Half-Blood Prince (Harry...
# 6   [eng, en-US, nan, en-GB, en-CA, spa, fre, ger,...
# 7   [4.54, 4.46, 4.44, 4.53, 4.77, 4.73, 4.2, 4.37...
# 8   [1678823, 1735368, 4602479, 1832823, 1753043, ...
# 9   [https://images.gr-assets.com/books/1361039191...
# 10  [https://images.gr-assets.com/books/1361039191...
# 11  [\r\nWhen Harry Potter and the Half-Blood Prin...
# 12  [fantasy, science-fiction, history, travel, hu...
# 13  [https://images.gr-assets.com/books/1361039191...

# %%
df = df.drop(['medium_image_url', 'small_image_url', 'original_title', 'book_id'], axis=1) #mendrop kolom

# %% [markdown]
# ## HANDLING MISSING VALUES
# https://towardsdatascience.com/whats-the-best-way-to-handle-nan-values-62d50f738fc

# %% [markdown]
# ### original_publication_year

# %%
#original_publication_year
df[df['original_publication_year'].isna() == True].head(21)
# Out:
#       goodreads_book_id                                         authors  \
# 19                   36  Chris   Smith, Christopher Lee, Richard Taylor
# 933               11318                                Raymond Chandler
# 2569              48811                                   Carolyn Keene
# 3313              90072                       Robert Kapilow, Dr. Seuss
# 4264             197436                                   Gloria Levine
# 4877             349254                                     Jude Fisher
# 4882             351023                                     Jill Murphy
# 5514             765148                  Giles Andreae, Guy Parker-Rees
# 5584             809849                                    Rod Campbell
# 5675             856917                                      Yuu Watase
# 5791            1044141                                Stephen R. Covey
# 5798            1056627                                     Joel Osteen
# 6345            3609760                                  Mark Cotta Vaz
# 6482            5171894                                   James Rollins
# 6562            6054190                                      Jane Green
# 6835            6614886                                 أحمد خالد توفيق
# 7434            8724779                         P.C. Cast, Kristin Cast
# 7539            9528186                              Lambert M. Surhone
# 7595            9748274                                 Charles Dickens
# 7608            9832370                                        BookRags
# 8987           17733861                                   Bella Forrest
#
#       original_publication_year  \
# 19                          NaN
# 933                         NaN
# 2569                        NaN
# 3313                        NaN
# 4264                        NaN
# 4877                        NaN
# 4882                        NaN
# 5514                        NaN
# 5584                        NaN
# 5675                        NaN
# 5791                        NaN
# 5798                        NaN
# 6345                        NaN
# 6482                        NaN
# 6562                        NaN
# 6835                        NaN
# 7434                        NaN
# 7539                        NaN
# 7595                        NaN
# 7608                        NaN
# 8987                        NaN
#
#                                                   title language_code  \
# 19           The Lord of the Rings: Weapons and Warfare           eng
# 933                              Trouble Is My Business           eng
# 2569                                  Nancy Drew: #1-64           eng
# 3313  Dr. Seuss's Green Eggs and Ham: For Soprano, B...           NaN
# 4264  Ralph S. Mouse by Beverly Cleary: Teacher Guid...           NaN
# 4877  The Lord of the Rings: The Return of the King:...           eng
# 4882                  The Worst Witch (Worst Witch, #1)           NaN
# 5514                               Giraffes Can't Dance         en-US
# 5584                     Dear Zoo: A Lift-the-Flap Book           NaN
# 5675                         Absolute Boyfriend, Vol. 1           eng
# 5791     The 8th Habit: From Effectiveness to Greatness         en-US
# 5798  Become a Better You: 7 Keys to Improving Your ...           NaN
# 6345  Twilight: The Complete Illustrated Movie Compa...         en-US
# 6482                 The Doomsday Key (Sigma Force, #6)         en-US
# 6562                                          Dune Road           eng
# 6835                                             زغازيغ           ara
# 7434  Marked / Betrayed / Chosen / Untamed / Hunted ...           eng
# 7539                    Pretty Little Liars (TV Series)           eng
# 7595          A Tale of Two Cities / Great Expectations         en-US
# 7608               BookRags Summary:  A Storm of Swords           eng
# 8987          A Shade of Blood (A Shade of Vampire, #2)           eng
#
#       average_rating  ratings_count  \
# 19              4.53          18788
# 933             4.05           9020
# 2569            4.19          16743
# 3313            4.44          90574
# 4264            3.95          14513
# 4877            4.59          17526
# 4882            3.94          13003
# 5514            4.28          14144
# 5584            4.25          16432
# 5675            4.01          29385
# 5791            3.99          13765
# 5798            4.15           8553
# 6345            4.23         291411
# 6482            4.16          19510
# 6562            3.41          10608
# 6835            3.55           8944
# 7434            4.43          20578
# 7539            4.46          11643
# 7595            3.98          14912
# 7608            4.59          18960
# 8987            4.01          24757
#
#                                                    desc                genre  \
# 19    \r\nShe won't rest until she's sent every walk...              fantasy
# 933   \r\nSkulduggery Pleasant is lost on the other ...              mystery
# 2569  \r\nThirteenth-century Wales is a divided coun...              mystery
# 3313  \r\nThe Golden Compass, The Subtle Knife, and ...     children-s-books
# 4264  \r\nAuschwitz-Birkenau is the site of the larg...            childrens
# 4877  \r\nIt has been four months since a mysterious...              fantasy
# 4882  \r\nThe final book in the Regeneration Trilogy...              fantasy
# 5514  \r\nDANICA SHARDAE IS an avian shapeshifter, a...        picture-books
# 5584  \r\nA pampered millionaire's son tumbles overb...            childrens
# 5675  \r\nGraphic novel star Kazu Kibuishi creates a...                manga
# 5791  \r\nAmerican on Purpose: The Improbable Advent...             business
# 5798  \r\nThe life of Spokane Indian Thomas Builds-t...            self-help
# 6345  \r\nWHAT IS LOST...WILL BE FOUNDIn this stunni...             vampires
# 6482  \r\nAn Italian village on a hilltop near the A...        james-rollins
# 6562  \r\nThe Invincible Ninth Roman Legion Marches ...            chick-lit
# 6835  \r\nJacinda was supposed to bond with Cassian,...      أحمد-خالد-توفيق
# 7434  \r\nEnna and Princess Isi became fast friends ...             vampires
# 7539  \r\nNothing in her cultured East Coast upbring...  pretty-little-liars
# 7595  \r\nDespite her outgoing demeanor, Olivia is p...             classics
# 7608  \r\nThere are no rules in the dark, no place t...              fantasy
# 8987  \r\nA biting satire about a young man's isolat...   paranormal-romance
#
#                                               image_url
# 19    https://s.gr-assets.com/assets/nophoto/book/11...
# 933   https://images.gr-assets.com/books/1388189902l...
# 2569  https://s.gr-assets.com/assets/nophoto/book/11...
# 3313  https://s.gr-assets.com/assets/nophoto/book/11...
# 4264  https://s.gr-assets.com/assets/nophoto/book/11...
# 4877  https://s.gr-assets.com/assets/nophoto/book/11...
# 4882  https://s.gr-assets.com/assets/nophoto/book/11...
# 5514  https://images.gr-assets.com/books/1306505271l...
# 5584  https://images.gr-assets.com/books/1391337388l...
# 5675  https://s.gr-assets.com/assets/nophoto/book/11...
# 5791  https://s.gr-assets.com/assets/nophoto/book/11...
# 5798  https://s.gr-assets.com/assets/nophoto/book/11...
# 6345  https://images.gr-assets.com/books/1352539022l...
# 6482  https://images.gr-assets.com/books/1340970015l...
# 6562  https://s.gr-assets.com/assets/nophoto/book/11...
# 6835  https://s.gr-assets.com/assets/nophoto/book/11...
# 7434  https://images.gr-assets.com/books/1347018756l...
# 7539  https://images.gr-assets.com/books/1379594334l...
# 7595  https://s.gr-assets.com/assets/nophoto/book/11...
# 7608  https://images.gr-assets.com/books/1369340463l...
# 8987  https://images.gr-assets.com/books/1365199807l...

# %%
# https://www.goodreads.com
df.fillna(value={'original_publication_year':2003},limit=1,inplace=True)
df.fillna(value={'original_publication_year':1988},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2002},limit=1,inplace=True)
df.fillna(value={'original_publication_year':1995},limit=1,inplace=True)
df.fillna(value={'original_publication_year':1999},limit=1,inplace=True)
df.fillna(value={'original_publication_year':1955},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2004},limit=1,inplace=True)
df.fillna(value={'original_publication_year':1999},limit=1,inplace=True)
df.fillna(value={'original_publication_year':1982},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2011},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2004},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2007},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2008},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2009},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2009},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2009},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2009},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2010},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2010},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2010},limit=1,inplace=True)
df.fillna(value={'original_publication_year':2013},limit=1,inplace=True)

# %%
df['original_publication_year'] = df['original_publication_year'].astype('int')

# %% [markdown]
# ### genre

# %%
#genre
df[df['genre'].isna() == True].head(5)
# Out:
#       goodreads_book_id           authors  original_publication_year  \
# 959               11557   Robert McCammon                       1987
# 6913            6871737  Jennifer L. Holm                       2010
# 7102            7528717       Jeff Kinney                       2010
# 9416           20871704    Colleen Oakley                       2015
# 9636           23287179  Kim van Alkemade                       2015
#
#                                                  title language_code  \
# 959                                          Swan Song           eng
# 6913                                Turtle in Paradise         en-US
# 7102  The Wimpy Kid Movie Diary (Diary of a Wimpy Kid)         en-US
# 9416                                       Before I Go           NaN
# 9636                               Orphan Number Eight           eng
#
#       average_rating  ratings_count  \
# 959             4.28          38018
# 6913            3.93          14714
# 7102            4.16          15956
# 9416            3.79           8181
# 9636            3.69           9558
#
#                                                    desc genre  \
# 959   \r\nThe last live broadcast on Polish Radio, o...   NaN
# 6913  \r\nCarolyn's not so different from the other ...   NaN
# 7102  \r\nA New York Times bestselling epic. A block...   NaN
# 9416  \r\nJosie Tyrell, art model, runaway, and deni...   NaN
# 9636  \r\nWhen she is caught in the backseat of a ca...   NaN
#
#                                               image_url
# 959   https://images.gr-assets.com/books/1445981000l...
# 6913  https://s.gr-assets.com/assets/nophoto/book/11...
# 7102  https://images.gr-assets.com/books/1328811516l...
# 9416  https://images.gr-assets.com/books/1397917357l...
# 9636  https://images.gr-assets.com/books/1416424263l...

# %%
df.fillna(value={'genre':'horror'},limit=1,inplace=True)
df.fillna(value={'genre':'historical-fiction'},limit=1,inplace=True)
df.fillna(value={'genre':'non-fiction'},limit=1,inplace=True)
df.fillna(value={'genre':'romance'},limit=1,inplace=True)
df.fillna(value={'genre':'historical-fiction'},limit=1,inplace=True)

# %% [markdown]
# ### desc

# %%
#desc
df[df['desc'].isna() == True].head(2)
# Out:
#       goodreads_book_id         authors  original_publication_year  \
# 4265             197457     Erin Hunter                       2007
# 4868             347698  Kate Grenville                       2005
#
#                                          title language_code  average_rating  \
# 4265  The Sight (Warriors: Power of Three, #1)         en-US            4.27
# 4868                          The Secret River           eng            3.79
#
#       ratings_count desc               genre  \
# 4265          15904  NaN            warriors
# 4868          11051  NaN  historical-fiction
#
#                                               image_url
# 4265  https://images.gr-assets.com/books/1363489119l...
# 4868  https://s.gr-assets.com/assets/nophoto/book/11...

# %%
df.fillna(value={"dec":"The Sight is a children's fantasy novel. It was released on 24 April 2007, and it is the first installment of the Warriors: Power of Three series by Erin Hunter. The book was recommended as Children's Summer Reading by the Washington Post Children's Book Club."},limit=1,inplace=True)
df.fillna(value={"dec":"The Secret River is a 2005 historical novel by Kate Grenville about an early 19th-century Englishman transported to Australia for theft. The story explores what might have happened when Europeans colonised land already inhabited by Aboriginal people."},limit=1,inplace=True)

# %% [markdown]
# ### language_code

# %%
#language_code
df['language_code'].describe()
# Out:
# count     8916
# unique      25
# top        eng
# freq      6341
# Name: language_code, dtype: object

# %%
df['language_code'] = df['language_code'].fillna('eng')

# %% [markdown]
# ## DUPLICATED VALUES

# %%
df = df.drop_duplicates() # drop duplicated value
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9998 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   goodreads_book_id          9998 non-null   int64
#  1   authors                    9998 non-null   object
#  2   original_publication_year  9998 non-null   int64
#  3   title                      9998 non-null   object
#  4   language_code              9998 non-null   object
#  5   average_rating             9998 non-null   float64
#  6   ratings_count              9998 non-null   int64
#  7   desc                       9998 non-null   object
#  8   genre                      9998 non-null   object
#  9   image_url                  9998 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 859.2+ KB

# %%
df.to_csv("/content/drive/MyDrive/Colab Notebooks/PORTFOLIO GIOVALDI/RECOMMENDER SYSTEM/clean.csv",index=False)
